# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.kdeplot(df['sepal_width'])

# %%
sns.distplot( df["sepal_width"], bins=10)

# %%
sns.regplot(x=df["sepal_length"], y=df["petal_length"], marker="+", fit_reg=False)

# %%
sns.regplot(x=df["sepal_length"], y=df["petal_length"], marker="+", fit_reg=True)

# %%
sns.barplot(x=df["species"], y=df["sepal_length"])
